# %%
# %matplotlib notebook
import yt
yt.toggle_interactivity()
import os
os.getcwd()
# Out:
# Using matplotlib backend: nbAgg
# '/mnt/c/Users/OndrejPegoJaura/Projects/Logi/Analysis/KelvinHelmholtz'

# %%
ds = yt.load('../../Exec/hydro_tests/KH/plt00703.temp')
slc = yt.SlicePlot(ds, "z", ("gas", "density"), center=(0,-0.4,0))
slc.show()
# Out:
# yt : [INFO     ] 2022-01-13 16:23:38,961 Parameters: current_time              = 0.50057375669006
# yt : [INFO     ] 2022-01-13 16:23:38,962 Parameters: domain_dimensions         = [256 256   1]
# yt : [INFO     ] 2022-01-13 16:23:38,965 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-13 16:23:38,967 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-01-13 16:23:40,210 xlim = -0.500000 0.500000
# yt : [INFO     ] 2022-01-13 16:23:40,211 ylim = -0.900000 0.100000
# yt : [INFO     ] 2022-01-13 16:23:40,212 xlim = -0.500000 0.500000
# yt : [INFO     ] 2022-01-13 16:23:40,213 ylim = -0.900000 0.100000
# yt : [INFO     ] 2022-01-13 16:23:40,215 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img src="data:image/png;base64,..." width="1084.8">

# %%
ds = yt.load('../../Exec/hydro_tests/KH/plt02966.temp')
slc = yt.SlicePlot(ds, "z", ("gas", "density"), center=(0,-0.4,0))
slc.show()
# Out:
# yt : [INFO     ] 2022-01-13 16:24:58,194 Parameters: current_time              = 2.0
# yt : [INFO     ] 2022-01-13 16:24:58,196 Parameters: domain_dimensions         = [256 256   1]
# yt : [INFO     ] 2022-01-13 16:24:58,198 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-13 16:24:58,200 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-01-13 16:24:59,786 xlim = -0.500000 0.500000
# yt : [INFO     ] 2022-01-13 16:24:59,787 ylim = -0.900000 0.100000
# yt : [INFO     ] 2022-01-13 16:24:59,789 xlim = -0.500000 0.500000
# yt : [INFO     ] 2022-01-13 16:24:59,790 ylim = -0.900000 0.100000
# yt : [INFO     ] 2022-01-13 16:24:59,795 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img src="data:image/png;base64,..." width="1084.8">

# %%
ds = yt.load('../../Exec/hydro_tests/KH/plt00000.temp')
slc = yt.SlicePlot(ds, "z", ("gas", "velocity_x"), center=(0,-0.4,0))
slc.show()
# Out:
# yt : [INFO     ] 2022-01-13 16:26:22,190 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-01-13 16:26:22,192 Parameters: domain_dimensions         = [256 256   1]
# yt : [INFO     ] 2022-01-13 16:26:22,193 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-01-13 16:26:22,195 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-01-13 16:26:24,079 xlim = -0.500000 0.500000
# yt : [INFO     ] 2022-01-13 16:26:24,081 ylim = -0.900000 0.100000
# yt : [INFO     ] 2022-01-13 16:26:24,083 xlim = -0.500000 0.500000
# yt : [INFO     ] 2022-01-13 16:26:24,085 ylim = -0.900000 0.100000
# yt : [INFO     ] 2022-01-13 16:26:24,087 Making a fixed resolution buffer of (('gas', 'velocity_x')) 800 by 800
# <img src="data:image/png;base64,..." width="1084.8">

# %%
ds = yt.load('../../../Castro/Exec/hydro_tests/KH/plt02966.temp')
slc = yt.SlicePlot(ds, "z", ("gas", "density"), center=(0,-0.4,0))
slc.show()
# Out:
# ---------------------------------------------------------------------------
# YTAmbiguousDataType                       Traceback (most recent call last)
# /tmp/ipykernel_12827/2969889047.py in <module>
# ----> 1 ds = yt.load('../../../Castro/Exec/hydro_tests/KH/plt02966.temp')
#       2 slc = yt.SlicePlot(ds, "z", ("gas", "density"), center=(0,-0.4,0))
#       3 slc.show()
#
# ~/.local/lib/python3.8/site-packages/yt/loaders.py in load(fn, *args, **kwargs)
#      94
#      95     if len(candidates) > 1:
# ---> 96         raise YTAmbiguousDataType(fn, candidates)
#      97
#      98     raise YTUnidentifiedDataType(fn, *args, **kwargs)
#
# YTAmbiguousDataType: Multiple data type candidates for ../../../Castro/Exec/hydro_tests/KH/plt02966.temp
# The following independent classes were detected as valid :
# <class 'yt.frontends.boxlib.data_structures.CastroDataset'>
# <class 'yt.frontends.boxlib.data_structures.AMReXDataset'>
# ...
